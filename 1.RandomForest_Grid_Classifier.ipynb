# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
#howmany class in Target_Value. Balanced or imbalanced data
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent=dataset[['Age','EstimatedSalary','Gender_Male']]
dependent=dataset[['Purchased']]

# %%
independent.shape
# Out:
# (400, 3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=1/3,random_state=0)
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
X_train=sd.fit_transform(X_train)
X_test=sd.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
grid_param={'criterion':['gini','entropy','log_loss'],'max_features':['sqrt','log2',None],'n_estimators':[10,50,100]}
grid=GridSearchCV(RandomForestClassifier(),grid_param, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 50, 100]},
#              scoring='f1_weighted', verbose=3)

# %%
print("Confusion Matrix value for best parameter:{}".format(grid.best_params_))
# Out:
# Confusion Matrix value for best parameter:{'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
res=grid.cv_results_
table=pd.DataFrame.from_dict(res)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.047056      0.013875         0.016898        0.002019
# 1        0.156094      0.011783         0.017738        0.003089
# 2        0.287109      0.015299         0.020671        0.001496
# 3        0.032968      0.002131         0.012390        0.002480
# 4        0.150789      0.012471         0.019699        0.002359
# 5        0.262474      0.009331         0.018986        0.002331
# 6        0.036195      0.005266         0.012161        0.004018
# 7        0.147524      0.008447         0.015694        0.001653
# 8        0.251493      0.011165         0.019291        0.001846
# 9        0.030330      0.001080         0.011911        0.002100
# 10       0.132669      0.011346         0.017598        0.003880
# 11       0.252784      0.014869         0.023229        0.003025
# 12       0.031649      0.000568         0.010800        0.002048
# 13       0.128630      0.011807         0.017686        0.002843
# 14       0.253467      0.012560         0.018326        0.004225
# 15       0.031556      0.001471         0.012454        0.003424
# 16       0.139379      0.013930         0.017111        0.002776
# 17       0.267595      0.008314         0.017112        0.002511
# 18       0.032508      0.004624         0.012223        0.002173
# 19       0.141034      0.011077         0.012646        0.002930
# 20       0.258717      0.021247         0.016420        0.003641
# 21       0.031963      0.003019         0.010167        0.005277
# 22       0.132125      0.007926         0.016982        0.000457
# 23       0.267423      0.016884         0.018344        0.002160
# 24       0.032478      0.003504         0.012370        0.003896
# 25       0.158181      0.011445         0.010604        0.002113
# 26       0.219906      0.023426         0.009872        0.004151
#
#    param_criterion param_max_features param_n_estimators  \
# 0             gini               sqrt                 10
# 1             gini               sqrt                 50
# 2             gini               sqrt                100
# 3             gini               log2                 10
# 4             gini               log2                 50
# 5             gini               log2                100
# 6             gini               None                 10
# 7             gini               None                 50
# 8             gini               None                100
# 9          entropy               sqrt                 10
# 10         entropy               sqrt                 50
# 11         entropy               sqrt                100
# 12         entropy               log2                 10
# 13         entropy               log2                 50
# 14         entropy               log2                100
# 15         entropy               None                 10
# 16         entropy               None                 50
# 17         entropy               None                100
# 18        log_loss               sqrt                 10
# 19        log_loss               sqrt                 50
# 20        log_loss               sqrt                100
# 21        log_loss               log2                 10
# 22        log_loss               log2                 50
# 23        log_loss               log2                100
# 24        log_loss               None                 10
# 25        log_loss               None                 50
# 26        log_loss               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.826263
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.847141
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.826263
# 3   {'criterion': 'gini', 'max_features': 'log2', ...           0.847141
# 4   {'criterion': 'gini', 'max_features': 'log2', ...           0.826263
# 5   {'criterion': 'gini', 'max_features': 'log2', ...           0.847141
# 6   {'criterion': 'gini', 'max_features': None, 'n...           0.847141
# 7   {'criterion': 'gini', 'max_features': None, 'n...           0.826263
# 8   {'criterion': 'gini', 'max_features': None, 'n...           0.847141
# 9   {'criterion': 'entropy', 'max_features': 'sqrt...           0.804764
# 10  {'criterion': 'entropy', 'max_features': 'sqrt...           0.867478
# 11  {'criterion': 'entropy', 'max_features': 'sqrt...           0.847141
# 12  {'criterion': 'entropy', 'max_features': 'log2...           0.782557
# 13  {'criterion': 'entropy', 'max_features': 'log2...           0.847141
# 14  {'criterion': 'entropy', 'max_features': 'log2...           0.867478
# 15  {'criterion': 'entropy', 'max_features': None,...           0.826263
# 16  {'criterion': 'entropy', 'max_features': None,...           0.847141
# 17  {'criterion': 'entropy', 'max_features': None,...           0.826263
# 18  {'criterion': 'log_loss', 'max_features': 'sqr...           0.804764
# 19  {'criterion': 'log_loss', 'max_features': 'sqr...           0.867478
# 20  {'criterion': 'log_loss', 'max_features': 'sqr...           0.867478
# 21  {'criterion': 'log_loss', 'max_features': 'log...           0.826263
# 22  {'criterion': 'log_loss', 'max_features': 'log...           0.867478
# 23  {'criterion': 'log_loss', 'max_features': 'log...           0.867478
# 24  {'criterion': 'log_loss', 'max_features': None...           0.826263
# 25  {'criterion': 'log_loss', 'max_features': None...           0.826263
# 26  {'criterion': 'log_loss', 'max_features': None...           0.826263
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.868752           0.775815           0.906166
# 1            0.888107           0.851527           0.925272
# 2            0.907177           0.851527           0.925272
# 3            0.870047           0.795256           0.906166
# 4            0.849057           0.833323           0.944161
# 5            0.907177           0.851527           0.925272
# 6            0.868752           0.833323           0.887907
# 7            0.850809           0.851527           0.887907
# 8            0.850809           0.851527           0.887907
# 9            0.828959           0.832483           0.886792
# 10           0.888107           0.833323           0.906166
# 11           0.870047           0.851527           0.925272
# 12           0.850809           0.832483           0.925272
# 13           0.888107           0.851527           0.925272
# 14           0.870047           0.851527           0.925272
# 15           0.849057           0.851527           0.887907
# 16           0.850809           0.851527           0.906935
# 17           0.831253           0.833323           0.887907
# 18           0.849057           0.851527           0.925272
# 19           0.868752           0.851527           0.925272
# 20           0.888107           0.851527           0.925272
# 21           0.888107           0.851527           0.906166
# 22           0.888107           0.851527           0.925272
# 23           0.888107           0.851527           0.925272
# 24           0.828959           0.832483           0.868632
# 25           0.850809           0.851527           0.887907
# 26           0.868752           0.851527           0.887907
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.924528         0.860305        0.054031               26
# 1            0.962264         0.894862        0.043974                6
# 2            0.962264         0.894501        0.049402                8
# 3            0.903610         0.864444        0.040969               21
# 4            0.943699         0.879300        0.053284               13
# 5            0.943699         0.894963        0.039030                5
# 6            0.943041         0.876033        0.038322               16
# 7            0.943041         0.871910        0.040645               18
# 8            0.924528         0.872383        0.029992               17
# 9            0.924528         0.855505        0.043709               27
# 10           0.962264         0.891468        0.042885                9
# 11           0.943699         0.887537        0.039529               11
# 12           0.923510         0.862926        0.054937               24
# 13           0.962264         0.894862        0.043974                6
# 14           0.962264         0.895318        0.041738                3
# 15           0.905069         0.863965        0.028500               22
# 16           0.924528         0.876188        0.032797               15
# 17           0.924528         0.860655        0.039030               25
# 18           0.961755         0.878475        0.056834               14
# 19           0.943699         0.891346        0.036215               10
# 20           0.962264         0.898930        0.040146                1
# 21           0.924528         0.879318        0.035859               12
# 22           0.943041         0.895085        0.034407                4
# 23           0.962264         0.898930        0.040146                1
# 24           0.962264         0.863720        0.051618               23
# 25           0.924528         0.868207        0.034352               20
# 26           0.924528         0.871796        0.033268               19

# %%
y_pred=grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[78  7]
#  [ 5 44]]

# %%
#Classification confusion matrix report
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        85
#            1       0.86      0.90      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import roc_auc_score
roc=roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
roc
# Out:
# 0.9651860744297719
