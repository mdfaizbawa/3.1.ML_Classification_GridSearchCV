# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
#howmany class in Target_Value. Balanced or imbalanced data
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent=dataset[['Age','EstimatedSalary','Gender_Male']]
dependent=dataset[['Purchased']]

# %%
independent.shape
# Out:
# (400, 3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=1/3,random_state=0)
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
X_train=sd.fit_transform(X_train)
X_test=sd.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
grid_param={'criterion':['gini','entropy','log_loss'],'max_features':['sqrt','log2',None],'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeClassifier(),grid_param, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
print("Confusion Matrix value for best parameter:{}".format(grid.best_params_))
# Out:
# Confusion Matrix value for best parameter:{'criterion': 'gini', 'max_features': None, 'splitter': 'best'}

# %%
res=grid.cv_results_
table=pd.DataFrame.from_dict(res)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004914      0.001508         0.013288        0.002106
# 1        0.014964      0.010177         0.010328        0.003851
# 2        0.004761      0.004289         0.012999        0.002637
# 3        0.002017      0.002542         0.017738        0.003374
# 4        0.004072      0.002318         0.014942        0.002434
# 5        0.006433      0.003125         0.009939        0.000754
# 6        0.004150      0.002017         0.012045        0.002130
# 7        0.005838      0.000873         0.007045        0.003863
# 8        0.005014      0.004734         0.007422        0.005995
# 9        0.007109      0.008811         0.010814        0.008072
# 10       0.005345      0.005064         0.008506        0.004379
# 11       0.004155      0.004005         0.010256        0.002750
# 12       0.005839      0.004654         0.008971        0.007291
# 13       0.002927      0.002996         0.013589        0.002811
# 14       0.004422      0.005138         0.015039        0.003227
# 15       0.003408      0.000746         0.016445        0.003541
# 16       0.004866      0.000381         0.012990        0.005294
# 17       0.003003      0.002028         0.012418        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0             gini               sqrt           best
# 1             gini               sqrt         random
# 2             gini               log2           best
# 3             gini               log2         random
# 4             gini               None           best
# 5             gini               None         random
# 6          entropy               sqrt           best
# 7          entropy               sqrt         random
# 8          entropy               log2           best
# 9          entropy               log2         random
# 10         entropy               None           best
# 11         entropy               None         random
# 12        log_loss               sqrt           best
# 13        log_loss               sqrt         random
# 14        log_loss               log2           best
# 15        log_loss               log2         random
# 16        log_loss               None           best
# 17        log_loss               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.782557
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.867478
# 2   {'criterion': 'gini', 'max_features': 'log2', ...           0.826263
# 3   {'criterion': 'gini', 'max_features': 'log2', ...           0.826263
# 4   {'criterion': 'gini', 'max_features': None, 's...           0.849794
# 5   {'criterion': 'gini', 'max_features': None, 's...           0.787654
# 6   {'criterion': 'entropy', 'max_features': 'sqrt...           0.867478
# 7   {'criterion': 'entropy', 'max_features': 'sqrt...           0.812243
# 8   {'criterion': 'entropy', 'max_features': 'log2...           0.782557
# 9   {'criterion': 'entropy', 'max_features': 'log2...           0.812243
# 10  {'criterion': 'entropy', 'max_features': None,...           0.849794
# 11  {'criterion': 'entropy', 'max_features': None,...           0.804764
# 12  {'criterion': 'log_loss', 'max_features': 'sqr...           0.847141
# 13  {'criterion': 'log_loss', 'max_features': 'sqr...           0.832255
# 14  {'criterion': 'log_loss', 'max_features': 'log...           0.804764
# 15  {'criterion': 'log_loss', 'max_features': 'log...           0.849794
# 16  {'criterion': 'log_loss', 'max_features': None...           0.849794
# 17  {'criterion': 'log_loss', 'max_features': None...           0.905342
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.832918           0.813179           0.867097
# 1            0.808392           0.778067           0.796284
# 2            0.831253           0.832483           0.850543
# 3            0.776214           0.722205           0.886792
# 4            0.868752           0.833323           0.906935
# 5            0.832918           0.869709           0.924528
# 6            0.868752           0.795256           0.925272
# 7            0.846714           0.851527           0.888646
# 8            0.850809           0.793565           0.906166
# 9            0.868752           0.759244           0.795256
# 10           0.868752           0.814409           0.925272
# 11           0.776214           0.832483           0.831098
# 12           0.828959           0.814409           0.847020
# 13           0.787284           0.777291           0.886792
# 14           0.828959           0.851527           0.851527
# 15           0.868752           0.833323           0.870362
# 16           0.849057           0.850543           0.906935
# 17           0.852030           0.795256           0.832483
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.905069         0.840164        0.042514               12
# 1            0.826499         0.815344        0.030475               17
# 2            0.906166         0.849341        0.029579                9
# 3            0.903610         0.823017        0.067715               16
# 4            0.924528         0.876666        0.034265                1
# 5            0.883278         0.859617        0.046404                5
# 6            0.923510         0.876054        0.047602                4
# 7            0.885265         0.856879        0.028069                7
# 8            0.862442         0.839108        0.045717               13
# 9            0.905069         0.828113        0.052246               14
# 10           0.924528         0.876551        0.043160                2
# 11           0.826499         0.814211        0.021462               18
# 12           0.865054         0.840517        0.017341               11
# 13           0.847020         0.826128        0.040120               15
# 14           0.903610         0.848077        0.032709               10
# 15           0.868632         0.858173        0.014544                6
# 16           0.924528         0.876171        0.032780                3
# 17           0.862442         0.849510        0.036122                8

# %%
y_pred=grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[79  6]
#  [11 38]]

# %%
#Classification confusion matrix report
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        85
#            1       0.86      0.78      0.82        49
#
#     accuracy                           0.87       134
#    macro avg       0.87      0.85      0.86       134
# weighted avg       0.87      0.87      0.87       134

# %%
from sklearn.metrics import roc_auc_score
roc=roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
roc
# Out:
# 0.8524609843937575
