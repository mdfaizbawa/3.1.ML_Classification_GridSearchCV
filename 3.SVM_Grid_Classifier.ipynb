# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
#howmany class in Target_Value. Balanced or imbalanced data
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent=dataset[['Age','EstimatedSalary','Gender_Male']]
dependent=dataset[['Purchased']]

# %%
independent.shape
# Out:
# (400, 3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=1/3,random_state=0)
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
X_train=sd.fit_transform(X_train)
X_test=sd.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
grid_param={'kernel':['linear','poly','rbf','sigmoid'],'C':[10,100,1000,2000,3000,5000],'gamma':['scale','auto']}
grid=GridSearchCV(SVC(probability=True),grid_param, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000, 5000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
print("Confusion Matrix value for best parameter:{}".format(grid.best_params_))
# Out:
# Confusion Matrix value for best parameter:{'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
res=grid.cv_results_
table=pd.DataFrame.from_dict(res)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.028138      0.008778         0.015411        0.001631      10
# 1        0.022906      0.003420         0.018128        0.003457      10
# 2        0.015083      0.002016         0.013639        0.003598      10
# 3        0.014072      0.003003         0.011458        0.004439      10
# 4        0.018065      0.000985         0.014349        0.001463      10
# 5        0.017374      0.002775         0.015283        0.003492      10
# 6        0.018132      0.001346         0.011036        0.001335      10
# 7        0.011130      0.001733         0.013518        0.001927      10
# 8        0.055380      0.010337         0.013356        0.002668     100
# 9        0.080280      0.014146         0.009864        0.003749     100
# 10       0.021191      0.007419         0.011187        0.001560     100
# 11       0.018355      0.004443         0.013872        0.003464     100
# 12       0.055376      0.009007         0.011267        0.005740     100
# 13       0.066826      0.014832         0.013333        0.002305     100
# 14       0.025232      0.006621         0.010343        0.001298     100
# 15       0.013384      0.003926         0.014352        0.003988     100
# 16       0.269606      0.024784         0.008928        0.006225    1000
# 17       0.512020      0.157077         0.010262        0.002497    1000
# 18       0.054954      0.009566         0.011037        0.003266    1000
# 19       0.015438      0.002731         0.010036        0.001781    1000
# 20       0.309909      0.025465         0.009048        0.003481    1000
# 21       0.462431      0.045986         0.012602        0.002449    1000
# 22       0.048958      0.008837         0.011175        0.002783    1000
# 23       0.010964      0.002699         0.010621        0.003748    1000
# 24       0.596620      0.070707         0.008311        0.003531    2000
# 25       0.945460      0.243188         0.011621        0.004508    2000
# 26       0.083183      0.021508         0.009470        0.004458    2000
# 27       0.012409      0.002488         0.009881        0.003649    2000
# 28       0.575487      0.100950         0.012851        0.003120    2000
# 29       1.953932      1.906331         0.023988        0.029277    2000
# 30       0.319486      0.430419         0.010917        0.004832    2000
# 31       0.012917      0.002364         0.007961        0.004105    2000
# 32       3.605633      3.060989         0.040582        0.034425    3000
# 33       5.036185      3.034770         0.084289        0.072933    3000
# 34       0.352476      0.301640         0.030647        0.041049    3000
# 35       0.011793      0.004548         0.010368        0.001784    3000
# 36       4.062154      4.022417         0.030979        0.036782    3000
# 37       7.621631      4.216257         0.092820        0.088877    3000
# 38       0.341671      0.267592         0.044959        0.071699    3000
# 39       0.010569      0.003029         0.010090        0.002190    3000
# 40       7.225621      2.289894         0.113706        0.101962    5000
# 41      11.743270      5.287630         0.010609        0.002995    5000
# 42       0.460531      0.588667         0.011601        0.004406    5000
# 43       0.234285      0.077699         0.079781        0.067914    5000
# 44       8.482185      4.337931         0.054243        0.054009    5000
# 45       9.893071      7.139689         0.012410        0.004663    5000
# 46       1.123443      0.205180         0.015985        0.004345    5000
# 47       0.103154      0.045977         0.106267        0.089011    5000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale         poly
# 26       scale          rbf
# 27       scale      sigmoid
# 28        auto       linear
# 29        auto         poly
# 30        auto          rbf
# 31        auto      sigmoid
# 32       scale       linear
# 33       scale         poly
# 34       scale          rbf
# 35       scale      sigmoid
# 36        auto       linear
# 37        auto         poly
# 38        auto          rbf
# 39        auto      sigmoid
# 40       scale       linear
# 41       scale         poly
# 42       scale          rbf
# 43       scale      sigmoid
# 44        auto       linear
# 45        auto         poly
# 46        auto          rbf
# 47        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 1       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 2        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 3    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.762677
# 4      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 5        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 6         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 7     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.762677
# 8    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 9      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 10      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.808927
# 12    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 13      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 14       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 15   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.808927
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 17    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 18     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.847141
# 19  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 20   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 21     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 22      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 23  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 24  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 25    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 26     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 27  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 28   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 29     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 30      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 31  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 32  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 33    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 34     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 35  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 36   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 37     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 38      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 39  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 40  {'C': 5000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 41    {'C': 5000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 42     {'C': 5000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 43  {'C': 5000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 44   {'C': 5000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 45     {'C': 5000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 46      {'C': 5000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 47  {'C': 5000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.790949           0.698235           0.923510
# 1            0.808392           0.787943           0.924528
# 2            0.886792           0.869709           0.944161
# 3            0.738916           0.753180           0.778067
# 4            0.790949           0.698235           0.923510
# 5            0.808392           0.787943           0.924528
# 6            0.886792           0.869709           0.944161
# 7            0.738916           0.655795           0.796284
# 8            0.790949           0.698235           0.923510
# 9            0.787284           0.766556           0.924528
# 10           0.886792           0.870362           0.944161
# 11           0.714931           0.698113           0.796284
# 12           0.790949           0.698235           0.923510
# 13           0.787284           0.766556           0.924528
# 14           0.886792           0.870362           0.944161
# 15           0.714931           0.633719           0.718497
# 16           0.790949           0.698235           0.923510
# 17           0.765553           0.766556           0.924528
# 18           0.866968           0.851527           0.925272
# 19           0.714931           0.698113           0.796284
# 20           0.790949           0.698235           0.923510
# 21           0.765553           0.766556           0.924528
# 22           0.866968           0.851527           0.925272
# 23           0.714931           0.698113           0.796284
# 24           0.790949           0.698235           0.923510
# 25           0.765553           0.766556           0.924528
# 26           0.866968           0.851527           0.886792
# 27           0.714931           0.698113           0.796284
# 28           0.790949           0.698235           0.923510
# 29           0.765553           0.766556           0.924528
# 30           0.866968           0.851527           0.886792
# 31           0.714931           0.698113           0.796284
# 32           0.790949           0.698235           0.923510
# 33           0.765553           0.766556           0.924528
# 34           0.866968           0.851527           0.847020
# 35           0.714931           0.698113           0.796284
# 36           0.790949           0.698235           0.923510
# 37           0.765553           0.766556           0.924528
# 38           0.866968           0.851527           0.847020
# 39           0.714931           0.698113           0.796284
# 40           0.790949           0.698235           0.923510
# 41           0.765553           0.766556           0.924528
# 42           0.866968           0.851527           0.847020
# 43           0.714931           0.698113           0.796284
# 44           0.790949           0.698235           0.923510
# 45           0.765553           0.766556           0.924528
# 46           0.866968           0.851527           0.847020
# 47           0.714931           0.698113           0.796284
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.901744         0.818146        0.083619               25
# 1            0.901744         0.844445        0.056918               13
# 2            0.943041         0.902236        0.034431                3
# 3            0.766556         0.759879        0.013172               37
# 4            0.901744         0.818146        0.083619               25
# 5            0.901744         0.844445        0.056918               13
# 6            0.943041         0.902236        0.034431                3
# 7            0.766556         0.744045        0.047743               47
# 8            0.901744         0.818146        0.083619               25
# 9            0.901744         0.840441        0.062370               15
# 10           0.943041         0.902367        0.034308                1
# 11           0.766556         0.756962        0.043745               38
# 12           0.901744         0.818146        0.083619               25
# 13           0.901744         0.840441        0.062370               15
# 14           0.943041         0.902367        0.034308                1
# 15           0.766556         0.728526        0.058625               48
# 16           0.901744         0.818146        0.083619               25
# 17           0.901744         0.836095        0.066541               17
# 18           0.923510         0.882884        0.034529                5
# 19           0.766556         0.756962        0.043745               38
# 20           0.901744         0.818146        0.083619               25
# 21           0.901744         0.836095        0.066541               17
# 22           0.923510         0.878708        0.039503                6
# 23           0.766556         0.753527        0.040048               43
# 24           0.901744         0.818146        0.083619               25
# 25           0.901744         0.836095        0.066541               17
# 26           0.903610         0.867032        0.026948                7
# 27           0.766556         0.756962        0.043745               38
# 28           0.901744         0.818146        0.083619               25
# 29           0.901744         0.836095        0.066541               17
# 30           0.903610         0.867032        0.026948                7
# 31           0.766556         0.753527        0.040048               43
# 32           0.901744         0.818146        0.083619               25
# 33           0.901744         0.836095        0.066541               17
# 34           0.883278         0.855011        0.019206                9
# 35           0.766556         0.756962        0.043745               38
# 36           0.901744         0.818146        0.083619               25
# 37           0.901744         0.836095        0.066541               17
# 38           0.883278         0.855011        0.019206                9
# 39           0.766556         0.753527        0.040048               43
# 40           0.901744         0.818146        0.083619               25
# 41           0.901744         0.836095        0.066541               17
# 42           0.883278         0.855011        0.019206                9
# 43           0.766556         0.756962        0.043745               38
# 44           0.901744         0.818146        0.083619               25
# 45           0.901744         0.836095        0.066541               17
# 46           0.883278         0.855011        0.019206                9
# 47           0.766556         0.753527        0.040048               43

# %%
y_pred=grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[80  5]
#  [ 7 42]]

# %%
#Classification confusion matrix report
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import roc_auc_score
roc=roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
roc
# Out:
# 0.9539015606242497
